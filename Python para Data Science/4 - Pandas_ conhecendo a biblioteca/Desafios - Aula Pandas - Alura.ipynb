# %% [markdown]
# #**Bora Praticar!**

# %% [markdown]
# # Aula 1

# %% [markdown]
# Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar algumas análises utilizando um arquivo csv diferente: alunos.csv.
#
# 1) Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.
#
# 2) Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.
#
# 3) Confira a quantidade de linhas e colunas desse DataFrame.
#
# 4) Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.
#
# Extra: Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc). Dica: pesquise pelo método describe.

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'

# %%
dados = pd.read_csv(url)
dados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
dados.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
dados.tail(5)
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %%
dados.shape
# Out:
# (18, 4)

# %%
dados.columns
# Out:
# Index(['Nome', 'Idade', 'Notas', 'Aprovado'], dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 578.0+ bytes

# %%
dados.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# # Aula 2

# %% [markdown]
# O time de ML chegou com algumas demandas de última hora para resolvermos nesse momento da análise exploratória. Essas demandas são:
#
# 1) Calcular a média de quartos por apartamento;
#
# 2) Conferir quantos bairros únicos existem na nossa base de dados;
#
# 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;
#
# 4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
url = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv"
dados = pd.read_csv(url, delimiter=";")
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         NaN     NaN
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     NaN
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
df = dados.query('@imoveis_comerciais not in Tipo')
df
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# 5      1200.0         NaN   NaN
# ...       ...         ...   ...
# 32953   900.0       490.0  48.0
# 32955   800.0       350.0  25.0
# 32956  1800.0       800.0  40.0
# 32957  1400.0       509.0  37.0
# 32958  3000.0       760.0   NaN
#
# [23111 rows x 9 columns]

# %%
# 1) Calcular a média de quartos por apartamento;
df['Quartos'].mean()

#2) Conferir quantos bairros únicos existem na nossa base de dados;

df['Bairro'].unique()
len(df['Bairro'].unique())
# Out:
# 154

# %%
df['Bairro'].nunique()
# Out:
# 154

# %%
#3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;
df = df.groupby('Bairro')[['Valor']].mean('valor').sort_values('Valor', ascending=False)
df.head()
# Out:
#                       Valor
# Bairro
# Joá            16773.478261
# Cidade Jardim  12000.000000
# Arpoador       10896.062500
# Paquetá        10550.000000
# Ipanema         9196.116863

# %%
#4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.
df.head().plot(kind = 'barh')
# Out:
# <Axes: ylabel='Bairro'>

# %% [markdown]
# # Aula 3

# %% [markdown]
# Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar alguns tratamentos e seleções utilizando um arquivo csv diferente: alunos.csv.
#
# Esse arquivo é o mesmo utilizado para resolução dos desafios da aula 1 e possui dados referentes a alunos de um curso superior.
#
# Com base nisso, solucione os problemas propostos abaixo utilizando os conhecimentos adquiridos até aqui.
#
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.
#
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.
#
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.
#
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".
#
# Extra: Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. Dica: pesquise pelo método replace.

# %%
#1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.
dados.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
dados['Notas'].interpolate(inplace = True)  # mais adequado para esta questão é usar o método fillna(), pois substitui a nota faltante por 0.

# %%
dados.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %%
#2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.
rem_alunos = dados.query('Nome == "Alice" | Nome == "Carlos"').index

# %%
dados.drop(rem_alunos, axis=0, inplace = True)

# %%
dados
# Out:
#          Nome  Idade      Notas  Aprovado
# 0         Ary     20   7.500000      True
# 1         Ana     18   5.000000     False
# 2       Cátia     27   2.500000     False
# 3       Denis     18   5.000000     False
# 4        Beto     21  10.000000      True
# 5       Bruna     23   8.500000     False
# 6        Dara     21   7.000000      True
# 9       Vitor     28   5.233333     False
# 10     Daniel     21   4.866667     False
# 11       Igor     24   4.500000     False
# 12  Sthefanie     26   9.500000      True
# 13      Mirla     25   9.000000      True
# 14      Paulo     37   8.000000     False
# 15     Mylena     29   7.000000      True
# 16      Lucas     33   7.500000     False
# 17      Nadia     34   8.000000      True

# %%
#3) Aplique um filtro que selecione apenas os alunos que foram aprovados.
aprovados = dados['Aprovado'] == True

# %%
dados[aprovados]
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
#4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".
alunos_aprovados = dados[aprovados]

dados.to_csv('alunos_aprovados.csv', index = False, sep = ';')

# %%
#Extra
alunos_aprovados.replace(7,8)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %%
alunos_aprovados = alunos_aprovados.replace(7,8)
alunos_aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# # Aula 4

# %% [markdown]
# Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar alguns tratamentos e seleções utilizando um arquivo csv diferente: alunos.csv.
#
# Esse arquivo é o mesmo utilizado para resolução dos desafios da aula 1 e 3 e possui dados referentes a alunos de um curso superior. Com base nisso, solucione os problemas propostos abaixo utilizando os conhecimentos adquiridos até aqui.
#
# 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.
#
# 2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.
#
# 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# False: caso o aluno esteja reprovado (nota final deve ser menor que 6).
# 4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %%
#1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.

dados['Pontos_extras'] = dados['Notas'] *0.4
dados
# Out:
#          Nome  Idade      Notas  Aprovado  Pontos_extras
# 0         Ary     20   7.500000      True       3.000000
# 1         Ana     18   5.000000     False       2.000000
# 2       Cátia     27   2.500000     False       1.000000
# 3       Denis     18   5.000000     False       2.000000
# 4        Beto     21  10.000000      True       4.000000
# 5       Bruna     23   8.500000     False       3.400000
# 6        Dara     21   7.000000      True       2.800000
# 9       Vitor     28   5.233333     False       2.093333
# 10     Daniel     21   4.866667     False       1.946667
# 11       Igor     24   4.500000     False       1.800000
# 12  Sthefanie     26   9.500000      True       3.800000
# 13      Mirla     25   9.000000      True       3.600000
# 14      Paulo     37   8.000000     False       3.200000
# 15     Mylena     29   7.000000      True       2.800000
# 16      Lucas     33   7.500000     False       3.000000
# 17      Nadia     34   8.000000      True       3.200000

# %%
#2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.

# %%
dados['Notas_finais'] = dados['Notas'] + dados['Pontos_extras']
dados
# Out:
#          Nome  Idade      Notas  Aprovado  Pontos_extras  Notas_finais
# 0         Ary     20   7.500000      True       3.000000     10.500000
# 1         Ana     18   5.000000     False       2.000000      7.000000
# 2       Cátia     27   2.500000     False       1.000000      3.500000
# 3       Denis     18   5.000000     False       2.000000      7.000000
# 4        Beto     21  10.000000      True       4.000000     14.000000
# 5       Bruna     23   8.500000     False       3.400000     11.900000
# 6        Dara     21   7.000000      True       2.800000      9.800000
# 9       Vitor     28   5.233333     False       2.093333      7.326667
# 10     Daniel     21   4.866667     False       1.946667      6.813333
# 11       Igor     24   4.500000     False       1.800000      6.300000
# 12  Sthefanie     26   9.500000      True       3.800000     13.300000
# 13      Mirla     25   9.000000      True       3.600000     12.600000
# 14      Paulo     37   8.000000     False       3.200000     11.200000
# 15     Mylena     29   7.000000      True       2.800000      9.800000
# 16      Lucas     33   7.500000     False       3.000000     10.500000
# 17      Nadia     34   8.000000      True       3.200000     11.200000

# %%
dados['Notas_finais'] = dados['Notas_finais'].apply(lambda x: 10 if x > 10 else x) # função para limitar as notas dos alunos ate 10.
dados
# Out:
#          Nome  Idade      Notas  Aprovado  Pontos_extras  Notas_finais
# 0         Ary     20   7.500000      True       3.000000     10.000000
# 1         Ana     18   5.000000     False       2.000000      7.000000
# 2       Cátia     27   2.500000     False       1.000000      3.500000
# 3       Denis     18   5.000000     False       2.000000      7.000000
# 4        Beto     21  10.000000      True       4.000000     10.000000
# 5       Bruna     23   8.500000     False       3.400000     10.000000
# 6        Dara     21   7.000000      True       2.800000      9.800000
# 9       Vitor     28   5.233333     False       2.093333      7.326667
# 10     Daniel     21   4.866667     False       1.946667      6.813333
# 11       Igor     24   4.500000     False       1.800000      6.300000
# 12  Sthefanie     26   9.500000      True       3.800000     10.000000
# 13      Mirla     25   9.000000      True       3.600000     10.000000
# 14      Paulo     37   8.000000     False       3.200000     10.000000
# 15     Mylena     29   7.000000      True       2.800000      9.800000
# 16      Lucas     33   7.500000     False       3.000000     10.000000
# 17      Nadia     34   8.000000      True       3.200000     10.000000

# %%
#3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:

dados['Aprovado_final'] = dados['Notas_finais'] >=6
dados
# Out:
#          Nome  Idade      Notas  Aprovado  Pontos_extras  Notas_finais  \
# 0         Ary     20   7.500000      True       3.000000     10.000000
# 1         Ana     18   5.000000     False       2.000000      7.000000
# 2       Cátia     27   2.500000     False       1.000000      3.500000
# 3       Denis     18   5.000000     False       2.000000      7.000000
# 4        Beto     21  10.000000      True       4.000000     10.000000
# 5       Bruna     23   8.500000     False       3.400000     10.000000
# 6        Dara     21   7.000000      True       2.800000      9.800000
# 9       Vitor     28   5.233333     False       2.093333      7.326667
# 10     Daniel     21   4.866667     False       1.946667      6.813333
# 11       Igor     24   4.500000     False       1.800000      6.300000
# 12  Sthefanie     26   9.500000      True       3.800000     10.000000
# 13      Mirla     25   9.000000      True       3.600000     10.000000
# 14      Paulo     37   8.000000     False       3.200000     10.000000
# 15     Mylena     29   7.000000      True       2.800000      9.800000
# 16      Lucas     33   7.500000     False       3.000000     10.000000
# 17      Nadia     34   8.000000      True       3.200000     10.000000
#
#     Aprovado_final
# 0             True
# 1             True
# 2            False
# 3             True
# 4             True
# 5             True
# 6             True
# 9             True
# 10            True
# 11            True
# 12            True
# 13            True
# 14            True
# 15            True
# 16            True
# 17            True

# %%
#4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

aprovados_depois_extras = dados.query('Aprovado_final == True & Notas < 6')
aprovados_depois_extras
# Out:
#       Nome  Idade     Notas  Aprovado  Pontos_extras  Notas_finais  \
# 1      Ana     18  5.000000     False       2.000000      7.000000
# 3    Denis     18  5.000000     False       2.000000      7.000000
# 9    Vitor     28  5.233333     False       2.093333      7.326667
# 10  Daniel     21  4.866667     False       1.946667      6.813333
# 11    Igor     24  4.500000     False       1.800000      6.300000
#
#     Aprovado_final
# 1             True
# 3             True
# 9             True
# 10            True
# 11            True
